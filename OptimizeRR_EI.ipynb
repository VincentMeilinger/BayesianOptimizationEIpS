# %%
import math

import torch
from torch import tensor
from botorch.models import SingleTaskGP
from botorch.fit import fit_gpytorch_model
from gpytorch.mlls import ExactMarginalLogLikelihood
from botorch.optim import optimize_acqf

from sklearn.kernel_ridge import KernelRidge
from sklearn.gaussian_process.kernels import RBF
from sklearn.metrics import mean_squared_error
import sklearn.datasets as ds
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import random
from plot import plot_prediction
import numpy as np

# %matplotlib inline

from plot import *

# %%
torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

dtype = torch.double
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Optimizing Test Functions with EIpS

# %%
torch.manual_seed(0)

# BO design points
x_ = torch.arange(-1., 1.0, 0.01)
y_ = torch.arange(-1., 1.0, 0.01)
x_axis, y_axis = torch.meshgrid(x_, y_)
grid = torch.rot90(torch.stack((x_axis, y_axis), 2))

X_ = grid.reshape(len(x_)*len(y_), 2)

# %% [markdown]
# ## Ridge Regression

# %%
#dataset = ds.load_iris()
dataset = ds.load_digits(n_class=2)
X = dataset.data
y = dataset.target

#X = X[y > 0]
#y = y[y > 0]
#y -= 1
scaler = StandardScaler()
X = scaler.fit_transform(X)

# test train split
#X, y = ds.make_moons(200, noise=0.3, random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# hyperparameter search space
gamma_min = -9.
gamma_max = 3 #3
llambda_min = -2
llambda_max = 10 #10
resolution = 13
gamma_space = (np.logspace(gamma_min, gamma_max, resolution, base=2))
llambda_space = (np.logspace(llambda_min, llambda_max, resolution, base=2))

def log_scale(x, min, max): # map from [-1, 1] to log2([min, max])
    return torch.exp2((max - min) * ((x+1)*0.5) + min)

def plot_KRR_space_test(scores, X_samples, gamma_space, llambda_space):
    gamma_scaled = log_scale(X_samples[:, 0], gamma_min, gamma_max)
    llambda_scaled = log_scale(X_samples[:, 1], llambda_min, llambda_max)

    p, ax = plt.subplots(figsize=(8, 6))
    ax.title.set_text("Validation accuracy")

    im=ax.imshow(
        np.rot90(scores),
        interpolation="nearest",
        cmap=plt.cm.hot,
        extent=[0, len(gamma_space), 0, len(llambda_space)]
    )
    plt.colorbar(im)

    ax.set_xticks(np.arange(len(gamma_space)))
    ax.set_xticklabels(gamma_space, rotation=45)
    ax.set_yticks(np.arange(len(llambda_space)))
    ax.set_yticklabels(llambda_space)

    plt.show()
    plt.figure(figsize=(8, 8))
    plt.scatter(gamma_scaled, llambda_scaled, c='green')
    plt.xlabel("gamma")
    plt.ylabel("lambda")
    plt.xscale('log', base=2)
    plt.xscale('log', base=2)
    plt.title("Sample Locations")
    plt.show()

def sample_regression(gamma, llambda, K=None, scale=True):
    if scale:
        gamma = log_scale(gamma, gamma_min, gamma_max)
        llambda = log_scale(llambda, llambda_min, llambda_max)

    gamma = float(gamma)
    llambda = float(llambda)
    # train
    kr = KernelRidge(alpha=llambda, gamma=gamma, kernel='precomputed')
    kernel = RBF(length_scale=gamma)
    if K is None:
        K = kernel.__call__(X_train)
    kr.fit(K, y_train)

    # test
    K_xX = kernel.__call__(X_test, Y=X_train)
    predictions = kr.predict(K_xX)
    score = mean_squared_error(y_test, predictions)

    return tensor(score), K

# %%
scores = torch.zeros((len(gamma_space), len(llambda_space)))
best_score = math.inf
best_candidate = [0, 0]
for ix, x_ax in enumerate(gamma_space):  # gamma
    for iy, y_ax in enumerate(llambda_space):  # llambda
        scores[ix][iy] = sample_regression(torch.tensor(x_ax),
                                           torch.tensor(y_ax),
                                           scale=False)[0]

        if scores[ix][iy] < best_score:
            best_score = scores[ix][iy]
            best_candidate = [x_ax, y_ax]

# %% [markdown]
# ## Bayesian Optimization

# %%
def sample_bo(n_iters:int, plot=False):
    bounds = tensor([[x_[0], y_[0]], [x_[-1], y_[-1]]])

    X_samples = tensor([[torch.rand((1)), torch.rand((1))]])
    y_samples = sample_regression(X_samples[:,0], X_samples[:,1])[0].reshape(-1, 1)
    print("=======================")
    print("initialization")
    print("candidate: ", X_samples[0])
    print("model score for candidate: ", float(y_samples[0]))

    for i in range(n_iters):
        print("=======================")
        print("iteration:      ", i)
        #print(X_samples)
        gp = SingleTaskGP(X_samples, y_samples)
        mll = ExactMarginalLogLikelihood(gp.likelihood, gp)
        fit_gpytorch_model(mll)

        EI = acqf.ExpectedImprovement(
            gp,
            y_samples.min(),
            maximize=False
        )

        # plot
        if plot:
            plot_bo(gp, EI, X_samples)

        best_candidate, acq_value = optimize_acqf(
            acq_function=EI,
            bounds=bounds,
            q=1,
            num_restarts=1,
            raw_samples=20
        )

        y_new_sample, K = sample_regression(best_candidate[0][0],
                                            best_candidate[0][1])
        #print("candidate: ", best_candidate)
        #print("model score for candidate: ", float(y_new_sample))

        X_samples = torch.vstack((X_samples, best_candidate))
        y_samples = torch.vstack((y_samples, y_new_sample))
    return y_samples


# params
n_samples = 50
n_bo = 15

plot = False

# measurements
improvement_mean = torch.zeros((n_bo+1, 1))
improvement_list = []
# bo sampling loop
p, ax = plt.subplots(figsize=(10, 10))

# only plot current best
# show simulated computation time on x-axis
for i in range(0, n_samples):
    print("::::::::::::::::::::::::::::::::::::::::::::::::::::")
    print("Sample ", i)
    result = sample_bo(n_bo, plot=plot)
    improvement = torch.tensor([result[0]])

    for j in range(1, len(result)):
        if improvement[-1] > result[j]:
            improvement = torch.vstack((improvement, result[j]))
        else:
            improvement = torch.vstack((improvement, improvement[-1]))

    improvement_mean += improvement
    improvement_list.append(improvement)
    ax.plot(np.arange(0, len(improvement), 1),
            improvement,
            '-.',
            color='blue',
            alpha = 0.3)

compute_time_steps = torch.arange(0, n_bo+1, 0.1)
improvement_list_scaled = []
for i in range(0, len(improvement_list)):
    current_improvement = improvement_list[i]
    current_compute_time = torch.arange(0, n_bo+1, 1)
    scaled_improvement = torch.zeros((len(compute_time_steps)), 1)
    iter = 0
    compute_time = 0
    for j in range(0, len(compute_time_steps)):
        imp = current_improvement[iter]
        if not iter + 1 > len(current_compute_time) -1:
            compute_time = current_compute_time[iter+1]
        scaled_improvement[j] = imp
        if compute_time_steps[j] >= compute_time:
            if iter < len(current_improvement)-1:
                iter += 1
    improvement_list_scaled.append(scaled_improvement)

# calculate mean
improvement_mean = torch.zeros((len(compute_time_steps), 1))
for improvement in improvement_list_scaled:
    improvement_mean += improvement
improvement_mean *= 1/n_samples

# calculate var
improvement_var = torch.zeros((len(improvement_mean), 1))
for i in range(0, n_samples):
    improvement_var += torch.square(improvement_list_scaled[i] - improvement_mean)
improvement_var *= 1/n_samples
improvement_var = torch.sqrt(improvement_var)

print("improvement_mean: ", improvement_mean)
print("improvement_var: ", improvement_var)

ax.plot(compute_time_steps,
        improvement_mean,
        color='red',
        label='mean')
ax.fill_between(compute_time_steps,
                (improvement_mean - improvement_var).flatten(),
                (improvement_mean + improvement_var).flatten(),
                alpha=0.3,
                color='red',
                label='standard deviation')
print("MEAN: ", improvement_mean)
print("VAR: ", improvement_var)
print("MEAN MAX: ", max(improvement_mean))
print("MEAN MIN: ", min(improvement_mean))
ax.set_xlabel("iteration")
ax.set_ylabel("y+")
ax.set_title("EI - best candidate in each iteration")
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.set_ylim([0., 0.6])
#ax.spines['right'].set_color('none')
#ax.spines['top'].set_color('none')
#ax.xaxis.set_ticks_position('bottom')
#ax.yaxis.set_ticks_position('left')

ax.legend()
plt.show()
# Out:
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  0
# =======================
# initialization
# candidate:  tensor([0.4963, 0.7682])
# model score for candidate:  0.4349862763600734
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  1
# =======================
# initialization
# candidate:  tensor([0.8092, 0.1434])
# model score for candidate:  0.20890841791165635
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  2
# =======================
# initialization
# candidate:  tensor([0.3178, 0.5333])
# model score for candidate:  0.4351727531129224
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  3
# =======================
# initialization
# candidate:  tensor([0.8289, 0.6118])
# model score for candidate:  0.36272465565609824
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  4
# =======================
# initialization
# candidate:  tensor([0.7070, 0.0762])
# model score for candidate:  0.32353112596596295
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  5
# =======================
# initialization
# candidate:  tensor([0.4769, 0.4982])
# model score for candidate:  0.43480243738039737
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  6
# =======================
# initialization
# candidate:  tensor([0.9717, 0.9804])
# model score for candidate:  0.38521204408476634
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  7
# =======================
# initialization
# candidate:  tensor([0.3744, 0.6961])
# model score for candidate:  0.43516674990110915
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  8
# =======================
# initialization
# candidate:  tensor([0.7190, 0.6664])
# model score for candidate:  0.4179812221069004
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  9
# =======================
# initialization
# candidate:  tensor([0.8921, 0.6577])
# model score for candidate:  0.3356414674387434
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  10
# =======================
# initialization
# candidate:  tensor([0.6706, 0.1608])
# model score for candidate:  0.37928943300967943
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  11
# =======================
# initialization
# candidate:  tensor([0.0907, 0.3516])
# model score for candidate:  0.4351851851348264
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  12
# =======================
# initialization
# candidate:  tensor([0.3532, 0.5640])
# model score for candidate:  0.43516355838447784
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  13
# =======================
# initialization
# candidate:  tensor([0.0369, 0.1389])
# model score for candidate:  0.43518518518516597
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  14
# =======================
# initialization
# candidate:  tensor([0.1215, 0.3933])
# model score for candidate:  0.4351851837838498
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  15
# =======================
# initialization
# candidate:  tensor([0.5835, 0.2512])
# model score for candidate:  0.4249373529003848
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  16
# =======================
# initialization
# candidate:  tensor([0.9861, 0.7565])
# model score for candidate:  0.324410906550671
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  17
# =======================
# initialization
# candidate:  tensor([0.5852, 0.9598])
# model score for candidate:  0.43458118115648586
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  18
# =======================
# initialization
# candidate:  tensor([0.2528, 0.1694])
# model score for candidate:  0.4351752135410023
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  19
# =======================
# initialization
# candidate:  tensor([0.0990, 0.1803])
# model score for candidate:  0.4351851849018161
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  20
# =======================
# initialization
# candidate:  tensor([0.3519, 0.6307])
# model score for candidate:  0.43516913787238753
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  21
# =======================
# initialization
# candidate:  tensor([0.2260, 0.9382])
# model score for candidate:  0.4351850316255701
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  22
# =======================
# initialization
# candidate:  tensor([0.2940, 0.7856])
# model score for candidate:  0.4351826182828389
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  23
# =======================
# initialization
# candidate:  tensor([0.0730, 0.1874])
# model score for candidate:  0.43518518517679117
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  24
# =======================
# initialization
# candidate:  tensor([0.7246, 0.5362])
# model score for candidate:  0.40459374041638513
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  25
# =======================
# initialization
# candidate:  tensor([0.9716, 0.4489])
# model score for candidate:  0.20985509162934135
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  26
# =======================
# initialization
# candidate:  tensor([0.1060, 0.7082])
# model score for candidate:  0.4351851851119556
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  27
# =======================
# initialization
# candidate:  tensor([0.6660, 0.6387])
# model score for candidate:  0.4262263300964958
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  28
# =======================
# initialization
# candidate:  tensor([0.1375, 0.7488])
# model score for candidate:  0.4351851837524198
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  29
# =======================
# initialization
# candidate:  tensor([0.8887, 0.7802])
# model score for candidate:  0.37098057137093515
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  30
# =======================
# initialization
# candidate:  tensor([0.3463, 0.3028])
# model score for candidate:  0.43512932515763125
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  31
# =======================
# initialization
# candidate:  tensor([0.3624, 0.3169])
# model score for candidate:  0.43511455666794746
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  32
# =======================
# initialization
# candidate:  tensor([0.8409, 0.1894])
# model score for candidate:  0.18932404687729362
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  33
# =======================
# initialization
# candidate:  tensor([0.4133, 0.4500])
# model score for candidate:  0.43507666629842373
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  34
# =======================
# initialization
# candidate:  tensor([0.6590, 0.4797])
# model score for candidate:  0.42013275772681064
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  35
# =======================
# initialization
# candidate:  tensor([0.9583, 0.9332])
# model score for candidate:  0.3794663711556097
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  36
# =======================
# initialization
# candidate:  tensor([0.3382, 0.4248])
# model score for candidate:  0.4351560958623215
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  37
# =======================
# initialization
# candidate:  tensor([0.9501, 0.7461])
# model score for candidate:  0.3343277461878978
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  38
# =======================
# initialization
# candidate:  tensor([0.8923, 0.7981])
# model score for candidate:  0.3734239613538971
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  39
# =======================
# initialization
# candidate:  tensor([0.8427, 0.8128])
# model score for candidate:  0.39580173385657996
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  40
# =======================
# initialization
# candidate:  tensor([0.8515, 0.0546])
# model score for candidate:  0.12603399790736822
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  41
# =======================
# initialization
# candidate:  tensor([0.9649, 0.4089])
# model score for candidate:  0.19524632127677752
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  42
# =======================
# initialization
# candidate:  tensor([0.0610, 0.4149])
# model score for candidate:  0.43518518518467714
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  43
# =======================
# initialization
# candidate:  tensor([0.6090, 0.1532])
# model score for candidate:  0.41227719609116203
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  44
# =======================
# initialization
# candidate:  tensor([0.4887, 0.7492])
# model score for candidate:  0.4350051448848788
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  45
# =======================
# initialization
# candidate:  tensor([0.7677, 0.5734])
# model score for candidate:  0.3903338064125156
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  46
# =======================
# initialization
# candidate:  tensor([0.2699, 0.5729])
# model score for candidate:  0.4351819268623067
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  47
# =======================
# initialization
# candidate:  tensor([0.7157, 0.4687])
# model score for candidate:  0.40014431170721837
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  48
# =======================
# initialization
# candidate:  tensor([0.9737, 0.5712])
# model score for candidate:  0.26001542009213147
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# ::::::::::::::::::::::::::::::::::::::::::::::::::::
# Sample  49
# =======================
# initialization
# candidate:  tensor([0.8017, 0.5305])
# model score for candidate:  0.36057602675804745
# =======================
# iteration:       0
# =======================
# iteration:       1
# =======================
# iteration:       2
# =======================
# iteration:       3
# =======================
# iteration:       4
# =======================
# iteration:       5
# =======================
# iteration:       6
# =======================
# iteration:       7
# =======================
# iteration:       8
# =======================
# iteration:       9
# =======================
# iteration:       10
# =======================
# iteration:       11
# =======================
# iteration:       12
# =======================
# iteration:       13
# =======================
# iteration:       14
# improvement_mean:  tensor([[0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156]])
# improvement_var:  tensor([[0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005]])
# MEAN:  tensor([[0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3851],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.3763],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.1826],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0411],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0293],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0209],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0203],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0189],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0174],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0165],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0164],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0160],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0159],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0157],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156],
#         [0.0156]])
# VAR:  tensor([[0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0775],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.0922],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1754],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.1060],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0461],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0261],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0107],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0099],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0072],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0033],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0015],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0010],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0009],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0006],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005],
#         [0.0005]])
# MEAN MAX:  tensor([0.3851])
# MEAN MIN:  tensor([0.0156])
